# %% [markdown]
# <a href="http://www.modelon.com/" target="_blank">
# <img style='float: left' src="data:image/png;base64,...">
# </a>
# </div>

# %%
from voila_basic_gui import VoilaGUI

gui = VoilaGUI()
gui.start()

# %% [markdown]
# Copyright (C) 2024 <a href="http://www.modelon.com/" target="_blank">Modelon</a>
